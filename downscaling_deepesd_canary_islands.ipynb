# %% [markdown]
# ## Downscaling with the DeepESD model

# %% [markdown]
# This notebook showcases a simple application of deep4downscaling for the statistical downscaling of precipitation. To do so, we will implement the following actions:
#
# - Define and train the DeepESD architecture [1].
# - Downscale and evaluate results over a test period.

# %% [markdown]
# ### Train the model

# %%
DATA_PATH = './data/input'
FIGURES_PATH = './figures'
MODELS_PATH = './models'
ASYM_PATH = './data/asym'

# %% [markdown]
# When working with climate data, xarray is an essential library, and deep4downscaling heavily relies on it. For the deep learning component, deep4downscaling uses PyTorch, one of the most popular frameworks in the field.

# %%
import numpy as np
import xarray as xr
import torch
from torch.utils.data import DataLoader, random_split

import os
import sys; sys.path.append('/current_folder')
import deep4downscaling.viz
import deep4downscaling.trans
import deep4downscaling.deep.loss
import deep4downscaling.deep.utils
import deep4downscaling.deep.models
import deep4downscaling.deep.train
import deep4downscaling.deep.pred
import deep4downscaling.metrics
import deep4downscaling.metrics_ccs

# %% [markdown]
# We will begin by loading the predictor. In this case, we select various large-scale variables from ERA5 at different height levels. These variables are already stored in a NetCDF file, the standard data format for deep4downscaling. Unfortunately, due to GitHub's size restrictions, we are unable to upload these files to the repository. However, the following cells provide an overview of the data, making it straightforward to reproduce this notebook with a similar file.

# %%
# Load predictors
predictor_filename = f'{DATA_PATH}/ERA5_NorthAtlanticRegion_1-5dg_full.nc'
predictor = xr.open_dataset(predictor_filename)

# %%
predictor
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 42, lat: 31, time: 16071)
# Coordinates:
#   * lon      (lon) float64 -39.0 -37.5 -36.0 -34.5 -33.0 ... 18.0 19.5 21.0 22.5
#   * lat      (lat) float64 23.5 25.0 26.5 28.0 29.5 ... 62.5 64.0 65.5 67.0 68.5
#   * time     (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2022-12-31
# Data variables: (12/13)
#     t500     (time, lat, lon) float32 ...
#     t700     (time, lat, lon) float32 ...
#     t850     (time, lat, lon) float32 ...
#     q500     (time, lat, lon) float32 ...
#     q700     (time, lat, lon) float32 ...
#     q850     (time, lat, lon) float32 ...
#     ...       ...
#     v700     (time, lat, lon) float32 ...
#     v850     (time, lat, lon) float32 ...
#     u500     (time, lat, lon) float32 ...
#     u700     (time, lat, lon) float32 ...
#     u850     (time, lat, lon) float32 ...
#     msl      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2023-06-06 07:20:26 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %% [markdown]
# The deep4downscaling library provides several functions to facilitate an initial visualization of the data. For example, the `deep4downscaling.viz.multiple_map_plot` function allows you to visualize an `xarray.Dataset`. These functions rely on matplotlib and cartopy. By default, the figure is saved as a `.pdf` file in the path specified by the `output_path argument`.

# %%
deep4downscaling.viz.multiple_map_plot(data=predictor.mean('time'),
                                       output_path=f'./{FIGURES_PATH}/predictor_climatology.pdf')

# %% [markdown]
# The predictand is an `xarray.Dataset` containing a single variable (the target). In this notebook, we will focus on downscaling accumulated precipitation over the region of Canary Islands. The dataset used is ROCIO+_CAN 2.5km.

# %%
predictand_filename = os.path.join(DATA_PATH, "sfcan*.nc")

predictand = xr.open_mfdataset(
    predictand_filename,
    combine="by_coords"
)

# %% [markdown]
# We preprocess the predictand dataset by retaining only surface-level data (height = 0.0), renaming the precipitation variable to `pr`, and standardizing the time dimension to daily resolution. These steps ensure compatibility with the predictor dataset.

# %%
predictand = predictand.rename({'precipitation': 'pr'})
predictand = predictand.sel(height=0.0, drop=True)
predictand["time"] = predictand["time"].dt.floor("D")

# %%
predictand
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 12053, lon: 281, lat: 161)
# Coordinates:
#   * time     (time) datetime64[ns] 1990-01-01 1990-01-02 ... 2022-12-31
#   * lon      (lon) float64 -19.0 -18.98 -18.95 -18.93 ... -12.05 -12.02 -12.0
#   * lat      (lat) float64 26.5 26.52 26.55 26.57 ... 30.43 30.45 30.48 30.5
# Data variables:
#     pr       (time, lat, lon) float32 dask.array<chunksize=(1826, 161, 281), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     Title:        AEMET very High-resolution (0.025 deg) daily gridded precip...
#     institution:  Agencia Estatal de Meteorologia (AEMET, www.aemet.es)
#     history:      Creation year 2023
#     version:      1.0

# %% [markdown]
# Similar to the predictors, deep4downscaling can also be used for an initial visualization of the predictand.

# %%
day_to_viz = '10-04-2015'
deep4downscaling.viz.simple_map_plot(data=predictand.sel(time=day_to_viz),
                                     colorbar='hot_r', var_to_plot='pr',
                                     output_path=f'./{FIGURES_PATH}/predictand_day.pdf')

# %% [markdown]
# Deep4downscaling also includes several common preprocessing techniques used in statistical downscaling, such as removing NaN values, aligning datasets (e.g., across time), bias adjustment, and standardization, among others.

# %%
# Remove days with nans in the predictor
predictor = deep4downscaling.trans.remove_days_with_nans(predictor)

# Align both datasets in time
predictor, predictand = deep4downscaling.trans.align_datasets(predictor, predictand, 'time')
predictor.load()
predictand.load()
# Out:
# There are no observations containing null values
# <xarray.Dataset>
# Dimensions:  (time: 12053, lon: 281, lat: 161)
# Coordinates:
#   * time     (time) datetime64[ns] 1990-01-01 1990-01-02 ... 2022-12-31
#   * lon      (lon) float64 -19.0 -18.98 -18.95 -18.93 ... -12.05 -12.02 -12.0
#   * lat      (lat) float64 26.5 26.52 26.55 26.57 ... 30.43 30.45 30.48 30.5
# Data variables:
#     pr       (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     Conventions:  CF-1.6
#     Title:        AEMET very High-resolution (0.025 deg) daily gridded precip...
#     institution:  Agencia Estatal de Meteorologia (AEMET, www.aemet.es)
#     history:      Creation year 2023
#     version:      1.0

# %% [markdown]
# In this particular case, we restrict the predictand data to the Canary Islands region to prevent the model from learning patterns that are not representative of the target area, thereby reducing potential bias during training.

# %%
lat_mask = (predictand.lat >= 26.5) & (predictand.lat <= 28.13)
lon_mask = (predictand.lon >= -14) & (predictand.lon <= -12)

mask = lat_mask & lon_mask
mask_3d = mask.broadcast_like(predictand.pr)

predictand['pr'] = predictand.pr.where(~mask_3d, np.nan)

# %% [markdown]
# To adhere to the standard training/validation scheme in the machine learning field, we divide the predictors and predictand into training and test sets.

# %%
years_train = ('1990', '2015')
years_test = ('2016', '2022')

x_train = predictor.sel(time=slice(*years_train))
y_train = predictand.sel(time=slice(*years_train))

x_test = predictor.sel(time=slice(*years_test))
y_test = predictand.sel(time=slice(*years_test))

# %% [markdown]
# Before feeding the predictors to the deep learning model, we standardize them to have a mean of zero and a standard deviation of one. This is done using the `deep4downscaling.trans.standardize` function.

# %%
x_train_stand = deep4downscaling.trans.standardize(data_ref=x_train, data=x_train)

# %% [markdown]
# For training and inference, the data will be transformed into the torch.Tensor type. To facilitate the transition from NetCDF to torch.Tensor, especially when computing projections (predictions), we define a mask around the predictand to use throughout the entire workflow.

# %%
y_mask = deep4downscaling.trans.compute_valid_mask(y_train)

# %% [markdown]
# All deep learning models implemented in deep4downscaling flatten their output into a vector, standardizing its dimensions to the shape `(time, grid point)`.

# %%
y_train_stack = y_train.stack(gridpoint=('lat', 'lon'))
y_mask_stack = y_mask.stack(gridpoint=('lat', 'lon'))

# %% [markdown]
# The DeepESD architecture consists of a set of convolutional layers followed by a final dense layer. In our case, since the predictand contains NaN values for sea grid points, we filter out these grid points to save computation. This reduces the number of neurons in the final fully connected layer. By applying this operation using the mask, the conversion between the model's output and the corresponding NetCDF becomes straightforward.

# %%
y_mask_stack_filt = y_mask_stack.where(y_mask_stack==1, drop=True)
y_train_stack_filt = y_train_stack.where(y_train_stack['gridpoint'] == y_mask_stack_filt['gridpoint'],
                                             drop=True)

# %% [markdown]
# The deep4downscaling library includes various loss functions for training deep learning models. In this notebook, we follow [2] and focus on the ASYmmetric loss function (ASYM). We have provided the values asym_weight=3 and cdf_weight=10 as an example of the flexibility of the loss function. Default values of asym_weight=1 and cdf_weight=2 are equivalent to the original loss.Asym at [3].Implementing custom loss functions should be straightforward, as they follow the typical PyTorch conventions.

# %%
loss_function = deep4downscaling.deep.loss.Asym(ignore_nans=True,
                                                asym_path=ASYM_PATH)

# %% [markdown]
# For this loss function to work, we need to pre-compute a gamma distribution for each grid point in the predictand data (training set) on a yearly basis and calculate the mean of their parameters (see [3] for more details). This process can be handled by deep4downscaling.

# %%
if loss_function.parameters_exist():
    loss_function.load_parameters()
else:
    loss_function.compute_parameters(data=y_train_stack_filt,
                                     var_target='pr')

# %% [markdown]
# NetCDF is not well-suited for use with PyTorch (or for converting to the `torch.Tensor` type). In contrast, NumPy is.

# %%
x_train_stand_arr = deep4downscaling.trans.xarray_to_numpy(x_train_stand)
y_train_arr = deep4downscaling.trans.xarray_to_numpy(y_train_stack_filt)

# %% [markdown]
# With our data now in the numpy format, we can create the `torch.Dataset` and `torch.DataLoader` to feed batches of data to the deep learning model during training.

# %%
# Create Dataset
train_dataset = deep4downscaling.deep.utils.StandardDataset(x=x_train_stand_arr,
                                                            y=y_train_arr)

# Split into training and validation sets
train_dataset, valid_dataset = random_split(train_dataset,
                                            [0.9, 0.1])

# Create DataLoaders
batch_size = 64

train_dataloader = DataLoader(train_dataset, batch_size=batch_size,
                              shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size,
                              shuffle=True)

# %% [markdown]
# Deep4downscaling includes several predefined deep learning architectures (e.g., DeepESD and U-Net), but custom architectures can be easily defined using the standard PyTorch framework. However, because deep4downscaling relies on a final flattening operation (as mentioned earlier), we recommend reviewing the implementations in `deep4downscaling.deep.models` and using them as a foundation.
#
# While deep4downscaling lacks a formal documentation page, all its functions and arguments are properly documented within the code.

# %%
# ?deep4downscaling.deep.models.DeepESDpr
# Out:
# Init signature:
# deep4downscaling.deep.models.DeepESDpr(
#     x_shape: tuple,
#     y_shape: tuple,
#     filters_last_conv: int,
#     stochastic: bool,
#     last_relu: bool = False,
# )
# Docstring:
# DeepESD model as proposed in Baño-Medina et al. 2024 for precipitation
# downscaling. This implementation allows for a deterministic (MSE-based)
# and stochastic (NLL-based) definition.
#
# Baño-Medina, J., Manzanas, R., Cimadevilla, E., Fernández, J., González-Abad,
# J., Cofiño, A. S., and Gutiérrez, J. M.: Downscaling multi-model climate projection
# ensembles with deep learning (DeepESD): contribution to CORDEX EUR-44, Geosci. Model
# Dev., 15, 6747–6758, https://doi.org/10.5194/gmd-15-6747-2022, 2022.
#
# Parameters
# ----------
# x_shape : tuple
#     Shape of the data used as predictor. This must have dimension 4
#     (time, channels/variables, lon, lat).
#
# y_shape : tuple
#     Shape of the data used as predictand. This must have dimension 2
#     (time, gridpoint)
#
# filters_last_conv : int
#     Number of filters/kernels of the last convolutional layer
#
# stochastic: bool
#     If set to True, the model is composed of three final dense layers computing
#     the p, shape and scale of the Bernoulli-gamma distribution. Otherwise,
#     the models is composed of one final layer computing the values.
#
# last_relu: bool, optional
#     If set to True, the output of the last dense layer is passed through a
#     ReLU activation function. This does not apply when stochastic=True. By
#     default is set to False.
# Init docstring: Initialize internal Module state, shared by both nn.Module and ScriptModule.
# File:           ~/Desktop/d4d-fork/deep4downscaling/deep4downscaling/deep/models.py
# Type:           type
# Subclasses:

# %% [markdown]
# In this notebook, we will train the DeepESD architecture with a single final convolutional layer.

# %%
model_name = 'deepesd_pr'
model = deep4downscaling.deep.models.DeepESDpr(x_shape=x_train_stand_arr.shape,
                                               y_shape=y_train_arr.shape,
                                               filters_last_conv=1,
                                               stochastic=False)

# %% [markdown]
# We set the typical training hyperparameters, as is commonly done in PyTorch.

# %%
num_epochs = 10000
patience_early_stopping = 20

learning_rate = 0.0001
optimizer = torch.optim.Adam(model.parameters(),
                             lr=learning_rate)

# %% [markdown]
# Deep learning models can run on either CPU or GPU devices. We provide the corresponding `.yml` environment files (`deep4downscaling/requirement`) to set up a basic Conda environment for running deep4downscaling.

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')

# Move ASYM paramters to device
loss_function.prepare_parameters(device=device)

# %% [markdown]
# Deep4downscaling provides the `deep4downscaling.deep.train.standard_training_loop`, which implements a basic training routine. Models are saved based on their performance on a validation set through an early stopping process, with the final saved model being the one that achieves the best score on this set. To disable early stopping, you can pass `None` to the `patience_early_stopping` argument. We recommend users consult the `?deep4downscaling.deep.train.standard_training_loop` for further details about this function.

# %%
train_loss, val_loss = deep4downscaling.deep.train.standard_training_loop(
                            model=model, model_name=model_name, model_path=MODELS_PATH,
                            device=device, num_epochs=num_epochs,
                            loss_function=loss_function, optimizer=optimizer,
                            train_data=train_dataloader, valid_data=valid_dataloader,
                            patience_early_stopping=patience_early_stopping)
# Out:
# Epoch 1 (32.98 secs) | Training Loss 1.2821 Valid Loss 1.5444 (Model saved)
# Epoch 2 (32.85 secs) | Training Loss 1.2801 Valid Loss 1.5329 (Model saved)
# Epoch 3 (35.97 secs) | Training Loss 1.2791 Valid Loss 1.5181 (Model saved)
# Epoch 4 (32.4 secs) | Training Loss 1.2797 Valid Loss 1.5373
# Epoch 5 (31.72 secs) | Training Loss 1.2783 Valid Loss 1.5192
# Epoch 6 (31.92 secs) | Training Loss 1.2809 Valid Loss 1.5253
# Epoch 7 (33.33 secs) | Training Loss 1.2851 Valid Loss 1.5191
# Epoch 8 (34.98 secs) | Training Loss 1.2787 Valid Loss 1.5214
# Epoch 9 (35.37 secs) | Training Loss 1.2782 Valid Loss 1.5409
# Epoch 10 (35.53 secs) | Training Loss 1.2766 Valid Loss 1.519
# Epoch 11 (35.56 secs) | Training Loss 1.28 Valid Loss 1.5269
# Epoch 12 (35.45 secs) | Training Loss 1.2786 Valid Loss 1.529
# Epoch 13 (35.26 secs) | Training Loss 1.2815 Valid Loss 1.5353
# Epoch 14 (35.13 secs) | Training Loss 1.2831 Valid Loss 1.5173 (Model saved)
# Epoch 15 (35.33 secs) | Training Loss 1.2816 Valid Loss 1.5265
# Epoch 16 (35.14 secs) | Training Loss 1.2819 Valid Loss 1.54
# Epoch 17 (35.17 secs) | Training Loss 1.2764 Valid Loss 1.5295
# Epoch 18 (35.2 secs) | Training Loss 1.2824 Valid Loss 1.521
# Epoch 19 (34.98 secs) | Training Loss 1.2839 Valid Loss 1.5218
# Epoch 20 (35.42 secs) | Training Loss 1.2803 Valid Loss 1.5238
# Epoch 21 (35.13 secs) | Training Loss 1.2804 Valid Loss 1.5517
# Epoch 22 (35.21 secs) | Training Loss 1.2787 Valid Loss 1.5209
# Epoch 23 (35.22 secs) | Training Loss 1.2788 Valid Loss 1.521
# Epoch 24 (35.25 secs) | Training Loss 1.2804 Valid Loss 1.5159 (Model saved)
# Epoch 25 (35.13 secs) | Training Loss 1.2809 Valid Loss 1.5183
# Epoch 26 (35.09 secs) | Training Loss 1.2805 Valid Loss 1.5322
# Epoch 27 (35.39 secs) | Training Loss 1.2834 Valid Loss 1.5189
# Epoch 28 (35.25 secs) | Training Loss 1.2774 Valid Loss 1.5288
# Epoch 29 (35.23 secs) | Training Loss 1.2795 Valid Loss 1.5347
# Epoch 30 (35.07 secs) | Training Loss 1.2815 Valid Loss 1.5264
# Epoch 31 (35.15 secs) | Training Loss 1.2779 Valid Loss 1.5248
# Epoch 32 (35.08 secs) | Training Loss 1.279 Valid Loss 1.5291
# Epoch 33 (35.08 secs) | Training Loss 1.2823 Valid Loss 1.5207
# Epoch 34 (35.34 secs) | Training Loss 1.2781 Valid Loss 1.5238
# Epoch 35 (35.27 secs) | Training Loss 1.279 Valid Loss 1.5555
# Epoch 36 (35.26 secs) | Training Loss 1.2789 Valid Loss 1.5256
# Epoch 37 (35.09 secs) | Training Loss 1.2782 Valid Loss 1.521
# Epoch 38 (35.3 secs) | Training Loss 1.2806 Valid Loss 1.523
# Epoch 39 (35.1 secs) | Training Loss 1.2841 Valid Loss 1.5185
# Epoch 40 (34.32 secs) | Training Loss 1.2763 Valid Loss 1.5159 (Model saved)
# Epoch 41 (34.7 secs) | Training Loss 1.276 Valid Loss 1.5211
# Epoch 42 (34.83 secs) | Training Loss 1.2765 Valid Loss 1.521
# Epoch 43 (34.88 secs) | Training Loss 1.2771 Valid Loss 1.5203
# Epoch 44 (34.95 secs) | Training Loss 1.2767 Valid Loss 1.5225
# Epoch 45 (34.96 secs) | Training Loss 1.2777 Valid Loss 1.5154 (Model saved)
# Epoch 46 (35.55 secs) | Training Loss 1.2781 Valid Loss 1.527
# Epoch 47 (35.43 secs) | Training Loss 1.2852 Valid Loss 1.525
# Epoch 48 (35.11 secs) | Training Loss 1.2781 Valid Loss 1.5171
# Epoch 49 (35.02 secs) | Training Loss 1.2794 Valid Loss 1.5441
# Epoch 50 (34.41 secs) | Training Loss 1.2755 Valid Loss 1.5348
# Epoch 51 (34.82 secs) | Training Loss 1.2785 Valid Loss 1.5184
# Epoch 52 (34.85 secs) | Training Loss 1.2775 Valid Loss 1.5197
# Epoch 53 (34.49 secs) | Training Loss 1.2741 Valid Loss 1.5195
# Epoch 54 (34.26 secs) | Training Loss 1.2733 Valid Loss 1.5138 (Model saved)
# Epoch 55 (33.33 secs) | Training Loss 1.2759 Valid Loss 1.5141
# Epoch 56 (33.05 secs) | Training Loss 1.2756 Valid Loss 1.5332
# Epoch 57 (32.52 secs) | Training Loss 1.2741 Valid Loss 1.5335
# Epoch 58 (32.17 secs) | Training Loss 1.2766 Valid Loss 1.5345
# Epoch 59 (31.95 secs) | Training Loss 1.2611 Valid Loss 1.4867 (Model saved)
# Epoch 60 (31.93 secs) | Training Loss 1.1717 Valid Loss 1.3912 (Model saved)
# Epoch 61 (31.92 secs) | Training Loss 1.1347 Valid Loss 1.3328 (Model saved)
# Epoch 62 (31.95 secs) | Training Loss 1.1112 Valid Loss 1.3283 (Model saved)
# Epoch 63 (31.69 secs) | Training Loss 1.1041 Valid Loss 1.3192 (Model saved)
# Epoch 64 (31.81 secs) | Training Loss 1.0917 Valid Loss 1.3039 (Model saved)
# Epoch 65 (32.03 secs) | Training Loss 1.0867 Valid Loss 1.3296
# Epoch 66 (32.19 secs) | Training Loss 1.0855 Valid Loss 1.2973 (Model saved)
# Epoch 67 (32.36 secs) | Training Loss 1.0737 Valid Loss 1.2948 (Model saved)
# Epoch 68 (31.95 secs) | Training Loss 1.0717 Valid Loss 1.2691 (Model saved)
# Epoch 69 (32.24 secs) | Training Loss 1.0643 Valid Loss 1.2631 (Model saved)
# Epoch 70 (31.82 secs) | Training Loss 1.0622 Valid Loss 1.2772
# Epoch 71 (31.32 secs) | Training Loss 1.0573 Valid Loss 1.2779
# Epoch 72 (31.76 secs) | Training Loss 1.0566 Valid Loss 1.2701
# Epoch 73 (31.98 secs) | Training Loss 1.0532 Valid Loss 1.2505 (Model saved)
# Epoch 74 (31.45 secs) | Training Loss 1.048 Valid Loss 1.2487 (Model saved)
# Epoch 75 (32.21 secs) | Training Loss 1.0496 Valid Loss 1.2594
# Epoch 76 (31.95 secs) | Training Loss 1.0393 Valid Loss 1.2541
# Epoch 77 (32.13 secs) | Training Loss 1.042 Valid Loss 1.2541
# Epoch 78 (32.04 secs) | Training Loss 1.0343 Valid Loss 1.2489
# Epoch 79 (31.93 secs) | Training Loss 1.0307 Valid Loss 1.2603
# Epoch 80 (32.04 secs) | Training Loss 1.0299 Valid Loss 1.2315 (Model saved)
# Epoch 81 (32.79 secs) | Training Loss 1.0323 Valid Loss 1.233
# Epoch 82 (33.2 secs) | Training Loss 1.0222 Valid Loss 1.2379
# Epoch 83 (32.76 secs) | Training Loss 1.0173 Valid Loss 1.2369
# Epoch 84 (32.22 secs) | Training Loss 1.0118 Valid Loss 1.2287 (Model saved)
# Epoch 85 (32.34 secs) | Training Loss 1.0073 Valid Loss 1.2214 (Model saved)
# Epoch 86 (32.97 secs) | Training Loss 1.0078 Valid Loss 1.2225
# Epoch 87 (32.66 secs) | Training Loss 1.0029 Valid Loss 1.2123 (Model saved)
# Epoch 88 (32.87 secs) | Training Loss 1.0034 Valid Loss 1.2084 (Model saved)
# Epoch 89 (32.82 secs) | Training Loss 0.9981 Valid Loss 1.1995 (Model saved)
# Epoch 90 (33.0 secs) | Training Loss 0.9932 Valid Loss 1.2016
# Epoch 91 (32.67 secs) | Training Loss 0.9925 Valid Loss 1.1925 (Model saved)
# Epoch 92 (33.82 secs) | Training Loss 0.9921 Valid Loss 1.1921 (Model saved)
# Epoch 93 (32.93 secs) | Training Loss 0.989 Valid Loss 1.1797 (Model saved)
# Epoch 94 (32.73 secs) | Training Loss 0.9869 Valid Loss 1.1808
# Epoch 95 (32.46 secs) | Training Loss 0.9791 Valid Loss 1.1869
# Epoch 96 (32.15 secs) | Training Loss 0.9824 Valid Loss 1.1887
# Epoch 97 (32.86 secs) | Training Loss 0.9793 Valid Loss 1.1836
# Epoch 98 (32.9 secs) | Training Loss 0.9784 Valid Loss 1.1884
# Epoch 99 (32.92 secs) | Training Loss 0.9774 Valid Loss 1.1875
# Epoch 100 (32.73 secs) | Training Loss 0.975 Valid Loss 1.1811
# Epoch 101 (32.7 secs) | Training Loss 0.9693 Valid Loss 1.2015
# Epoch 102 (32.72 secs) | Training Loss 0.9709 Valid Loss 1.1731 (Model saved)
# Epoch 103 (32.76 secs) | Training Loss 0.966 Valid Loss 1.1844
# Epoch 104 (32.61 secs) | Training Loss 0.9694 Valid Loss 1.1881
# Epoch 105 (32.16 secs) | Training Loss 0.9676 Valid Loss 1.1878
# Epoch 106 (32.48 secs) | Training Loss 0.9633 Valid Loss 1.1613 (Model saved)
# Epoch 107 (32.97 secs) | Training Loss 0.9601 Valid Loss 1.1643
# Epoch 108 (32.72 secs) | Training Loss 0.9625 Valid Loss 1.1582 (Model saved)
# Epoch 109 (32.65 secs) | Training Loss 0.9581 Valid Loss 1.1622
# Epoch 110 (32.97 secs) | Training Loss 0.962 Valid Loss 1.1751
# Epoch 111 (33.17 secs) | Training Loss 0.9588 Valid Loss 1.1525 (Model saved)
# Epoch 112 (33.14 secs) | Training Loss 0.955 Valid Loss 1.1544
# Epoch 113 (32.94 secs) | Training Loss 0.9586 Valid Loss 1.1488 (Model saved)
# Epoch 114 (32.52 secs) | Training Loss 0.9502 Valid Loss 1.1622
# Epoch 115 (32.57 secs) | Training Loss 0.951 Valid Loss 1.1644
# Epoch 116 (32.69 secs) | Training Loss 0.9496 Valid Loss 1.1534
# Epoch 117 (32.74 secs) | Training Loss 0.9473 Valid Loss 1.1498
# Epoch 118 (32.79 secs) | Training Loss 0.9468 Valid Loss 1.1515
# Epoch 119 (32.9 secs) | Training Loss 0.945 Valid Loss 1.1493
# Epoch 120 (32.75 secs) | Training Loss 0.9454 Valid Loss 1.1504
# Epoch 121 (32.9 secs) | Training Loss 0.9417 Valid Loss 1.1609
# Epoch 122 (32.65 secs) | Training Loss 0.9427 Valid Loss 1.1534
# Epoch 123 (32.21 secs) | Training Loss 0.9384 Valid Loss 1.1619
# Epoch 124 (32.34 secs) | Training Loss 0.945 Valid Loss 1.1427 (Model saved)
# Epoch 125 (32.83 secs) | Training Loss 0.9389 Valid Loss 1.1726
# Epoch 126 (32.06 secs) | Training Loss 0.9353 Valid Loss 1.1663
# Epoch 127 (32.63 secs) | Training Loss 0.9381 Valid Loss 1.1335 (Model saved)
# Epoch 128 (32.6 secs) | Training Loss 0.937 Valid Loss 1.1608
# Epoch 129 (32.74 secs) | Training Loss 0.9316 Valid Loss 1.1383
# Epoch 130 (32.75 secs) | Training Loss 0.9314 Valid Loss 1.1674
# Epoch 131 (32.43 secs) | Training Loss 0.9295 Valid Loss 1.1407
# Epoch 132 (32.37 secs) | Training Loss 0.9278 Valid Loss 1.182
# Epoch 133 (32.97 secs) | Training Loss 0.9281 Valid Loss 1.1422
# Epoch 134 (32.91 secs) | Training Loss 0.9284 Valid Loss 1.1299 (Model saved)
# Epoch 135 (32.56 secs) | Training Loss 0.9244 Valid Loss 1.1558
# Epoch 136 (32.94 secs) | Training Loss 0.9258 Valid Loss 1.1284 (Model saved)
# Epoch 137 (32.71 secs) | Training Loss 0.9263 Valid Loss 1.1288
# Epoch 138 (32.98 secs) | Training Loss 0.9221 Valid Loss 1.1589
# Epoch 139 (32.56 secs) | Training Loss 0.9246 Valid Loss 1.1278 (Model saved)
# Epoch 140 (32.59 secs) | Training Loss 0.9245 Valid Loss 1.1493
# Epoch 141 (32.96 secs) | Training Loss 0.9202 Valid Loss 1.1446
# Epoch 142 (32.88 secs) | Training Loss 0.9204 Valid Loss 1.1309
# Epoch 143 (33.22 secs) | Training Loss 0.9219 Valid Loss 1.1256 (Model saved)
# Epoch 144 (33.0 secs) | Training Loss 0.9188 Valid Loss 1.1429
# Epoch 145 (33.16 secs) | Training Loss 0.9129 Valid Loss 1.1421
# Epoch 146 (32.75 secs) | Training Loss 0.9106 Valid Loss 1.1277
# Epoch 147 (32.31 secs) | Training Loss 0.9123 Valid Loss 1.1447
# Epoch 148 (32.68 secs) | Training Loss 0.9116 Valid Loss 1.1423
# Epoch 149 (33.06 secs) | Training Loss 0.9138 Valid Loss 1.132
# Epoch 150 (33.07 secs) | Training Loss 0.9093 Valid Loss 1.1269
# Epoch 151 (32.73 secs) | Training Loss 0.9084 Valid Loss 1.1225 (Model saved)
# Epoch 152 (32.99 secs) | Training Loss 0.9113 Valid Loss 1.1223 (Model saved)
# Epoch 153 (32.97 secs) | Training Loss 0.9059 Valid Loss 1.1235
# Epoch 154 (33.07 secs) | Training Loss 0.9099 Valid Loss 1.1201 (Model saved)
# Epoch 155 (31.88 secs) | Training Loss 0.9092 Valid Loss 1.1352
# Epoch 156 (32.77 secs) | Training Loss 0.9055 Valid Loss 1.1263
# Epoch 157 (32.97 secs) | Training Loss 0.9046 Valid Loss 1.125
# Epoch 158 (32.91 secs) | Training Loss 0.9038 Valid Loss 1.1249
# Epoch 159 (33.16 secs) | Training Loss 0.9064 Valid Loss 1.1339
# Epoch 160 (33.16 secs) | Training Loss 0.9035 Valid Loss 1.1285
# Epoch 161 (33.33 secs) | Training Loss 0.9036 Valid Loss 1.117 (Model saved)
# Epoch 162 (32.71 secs) | Training Loss 0.9027 Valid Loss 1.1177
# Epoch 163 (32.51 secs) | Training Loss 0.9021 Valid Loss 1.132
# Epoch 164 (32.73 secs) | Training Loss 0.9007 Valid Loss 1.1357
# Epoch 165 (33.02 secs) | Training Loss 0.8976 Valid Loss 1.1309
# Epoch 166 (33.13 secs) | Training Loss 0.8982 Valid Loss 1.1533
# Epoch 167 (33.7 secs) | Training Loss 0.8996 Valid Loss 1.1189
# Epoch 168 (33.51 secs) | Training Loss 0.8932 Valid Loss 1.1354
# Epoch 169 (32.17 secs) | Training Loss 0.893 Valid Loss 1.126
# Epoch 170 (31.2 secs) | Training Loss 0.898 Valid Loss 1.1157 (Model saved)
# Epoch 171 (31.66 secs) | Training Loss 0.9004 Valid Loss 1.1216
# Epoch 172 (31.5 secs) | Training Loss 0.8915 Valid Loss 1.1237
# Epoch 173 (31.51 secs) | Training Loss 0.8939 Valid Loss 1.1592
# Epoch 174 (31.72 secs) | Training Loss 0.8911 Valid Loss 1.1325
# Epoch 175 (31.29 secs) | Training Loss 0.8917 Valid Loss 1.1334
# Epoch 176 (30.97 secs) | Training Loss 0.8889 Valid Loss 1.112 (Model saved)
# Epoch 177 (31.64 secs) | Training Loss 0.8892 Valid Loss 1.1323
# Epoch 178 (31.62 secs) | Training Loss 0.8878 Valid Loss 1.1297
# Epoch 179 (31.69 secs) | Training Loss 0.8837 Valid Loss 1.122
# Epoch 180 (31.9 secs) | Training Loss 0.8877 Valid Loss 1.1077 (Model saved)
# Epoch 181 (31.33 secs) | Training Loss 0.8842 Valid Loss 1.133
# Epoch 182 (31.15 secs) | Training Loss 0.8851 Valid Loss 1.1228
# Epoch 183 (31.41 secs) | Training Loss 0.8843 Valid Loss 1.1242
# Epoch 184 (31.81 secs) | Training Loss 0.8821 Valid Loss 1.1301
# Epoch 185 (31.79 secs) | Training Loss 0.8825 Valid Loss 1.1231
# Epoch 186 (31.65 secs) | Training Loss 0.8844 Valid Loss 1.1357
# Epoch 187 (30.91 secs) | Training Loss 0.88 Valid Loss 1.1324
# Epoch 188 (31.76 secs) | Training Loss 0.8821 Valid Loss 1.1217
# Epoch 189 (31.51 secs) | Training Loss 0.881 Valid Loss 1.1414
# Epoch 190 (31.78 secs) | Training Loss 0.8829 Valid Loss 1.1232
# Epoch 191 (31.77 secs) | Training Loss 0.8848 Valid Loss 1.1143
# Epoch 192 (31.66 secs) | Training Loss 0.8757 Valid Loss 1.1211
# Epoch 193 (30.76 secs) | Training Loss 0.88 Valid Loss 1.1328
# Epoch 194 (31.58 secs) | Training Loss 0.8791 Valid Loss 1.1262
# Epoch 195 (31.8 secs) | Training Loss 0.8786 Valid Loss 1.1344
# Epoch 196 (31.53 secs) | Training Loss 0.8763 Valid Loss 1.1182
# Epoch 197 (32.02 secs) | Training Loss 0.8765 Valid Loss 1.1082
# Epoch 198 (30.97 secs) | Training Loss 0.8745 Valid Loss 1.1096
# Epoch 199 (31.35 secs) | Training Loss 0.8709 Valid Loss 1.1077 (Model saved)
# Epoch 200 (31.69 secs) | Training Loss 0.8713 Valid Loss 1.124
# Epoch 201 (31.92 secs) | Training Loss 0.8723 Valid Loss 1.1202
# Epoch 202 (31.7 secs) | Training Loss 0.8736 Valid Loss 1.1449
# Epoch 203 (31.17 secs) | Training Loss 0.8752 Valid Loss 1.1273
# Epoch 204 (32.55 secs) | Training Loss 0.8681 Valid Loss 1.1235
# Epoch 205 (31.91 secs) | Training Loss 0.867 Valid Loss 1.1094
# Epoch 206 (31.77 secs) | Training Loss 0.8783 Valid Loss 1.1232
# Epoch 207 (32.08 secs) | Training Loss 0.8704 Valid Loss 1.1112
# Epoch 208 (31.29 secs) | Training Loss 0.8658 Valid Loss 1.1193
# Epoch 209 (31.23 secs) | Training Loss 0.8713 Valid Loss 1.1167
# Epoch 210 (32.03 secs) | Training Loss 0.8673 Valid Loss 1.1038 (Model saved)
# Epoch 211 (32.05 secs) | Training Loss 0.8686 Valid Loss 1.1134
# Epoch 212 (32.0 secs) | Training Loss 0.865 Valid Loss 1.1232
# Epoch 213 (31.57 secs) | Training Loss 0.8701 Valid Loss 1.1171
# Epoch 214 (31.18 secs) | Training Loss 0.8661 Valid Loss 1.1178
# Epoch 215 (31.39 secs) | Training Loss 0.8624 Valid Loss 1.1109
# Epoch 216 (33.61 secs) | Training Loss 0.8661 Valid Loss 1.1098
# Epoch 217 (35.36 secs) | Training Loss 0.864 Valid Loss 1.1414
# Epoch 218 (39.01 secs) | Training Loss 0.8641 Valid Loss 1.1217
# Epoch 219 (34.79 secs) | Training Loss 0.8595 Valid Loss 1.1288
# Epoch 220 (36.56 secs) | Training Loss 0.8633 Valid Loss 1.1224
# Epoch 221 (35.47 secs) | Training Loss 0.8605 Valid Loss 1.1265
# Epoch 222 (35.58 secs) | Training Loss 0.861 Valid Loss 1.1206
# Epoch 223 (35.42 secs) | Training Loss 0.865 Valid Loss 1.1167
# Epoch 224 (36.37 secs) | Training Loss 0.8608 Valid Loss 1.1285
# Epoch 225 (34.53 secs) | Training Loss 0.8555 Valid Loss 1.1087
# Epoch 226 (34.88 secs) | Training Loss 0.8604 Valid Loss 1.1049
# Epoch 227 (37.33 secs) | Training Loss 0.858 Valid Loss 1.1205
# Epoch 228 (36.25 secs) | Training Loss 0.8606 Valid Loss 1.1044
# Epoch 229 (32.34 secs) | Training Loss 0.8573 Valid Loss 1.1138
# Epoch 230 (32.84 secs) | Training Loss 0.8583 Valid Loss 1.1325
# ***Training finished***

# %% [markdown]
# ### Downscale the test set

# %% [markdown]
# Once a model has been trained and saved as a `.pt` file, it is easy to compute predictions on a new set of predictors. In this example, we will compute predictions on the test set, which was subset a few cells above. It is important to standardize the test data using the mean and standard deviation computed from the training set.

# %%
#Load the model weights into the DeepESD architecture
model.load_state_dict(torch.load(f'{MODELS_PATH}/{model_name}.pt'))

# Standardize
x_test_stand = deep4downscaling.trans.standardize(data_ref=x_train, data=x_test)

# Compute predictions
pred_test = deep4downscaling.deep.pred.compute_preds_standard(
                                x_data=x_test_stand, model=model,
                                device=device, var_target='pr',
                                mask=y_mask, batch_size=16)

# %%
# Visualize the predictions
deep4downscaling.viz.simple_map_plot(data=pred_test.mean('time'),
                                     colorbar='hot_r', var_to_plot='pr', vlimits=(0, 3.5),
                                     output_path=f'./{FIGURES_PATH}/prediction_test_mean.pdf') #TODO MSE

# %% [markdown]
# The `deep4downscaling.metrics` module, included within deep4downscaling, implements various metrics commonly used to assess deep learning models in the context of statistical downscaling. These include biases of different indices, spatial and probabilistic metrics, and multivariate indices, among others. In this example, we demonstrate its use by computing the relative bias of the Rx1day index between the target (test set) and the predictions for the winter months.

# %%
bias_rel_rx1day = deep4downscaling.metrics.bias_rel_rx1day(target=y_test, pred=pred_test,
                                                           var_target='pr', season='winter')

# %%
print(bias_rel_rx1day)
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 161, lon: 281)
# Coordinates:
#   * lat      (lat) float64 26.5 26.52 26.55 26.57 ... 30.43 30.45 30.48 30.5
#   * lon      (lon) float64 -19.0 -18.98 -18.95 -18.93 ... -12.05 -12.02 -12.0
# Data variables:
#     pr       (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan

# %% [markdown]
# Another commonly used metric is the relative bias with respect to the mean, which we will compute and visualize as an illustrative example.

# %%
bias_mean = deep4downscaling.metrics.bias_mean(target=y_test, pred=pred_test, var_target='pr')


deep4downscaling.viz.simple_map_plot(data=bias_mean,
                                     colorbar='hot_r', var_to_plot='pr', vlimits=(-2.5, 2.5),
                                     output_path=f'./{FIGURES_PATH}/bias_pred_test.pdf')

# %% [markdown]
# ### References

# %% [markdown]
# [1] Baño-Medina, J., Manzanas, R., Cimadevilla, E., Fernández, J., González-Abad, J., Cofiño, A. S., & Gutiérrez, J. M. (2022). Downscaling multi-model climate projection ensembles with deep learning (DeepESD): Contribution to CORDEX EUR-44. Geoscientific Model Development Discussions, 2022, 1-14.
#
# [2] González-Abad, J., & Gutiérrez, J. M. (2024). Are Deep Learning Methods Suitable for Downscaling Global Climate Projections? Review and Intercomparison of Existing Models. arXiv preprint arXiv:2411.05850.
#
# [3] Doury, A., Somot, S., & Gadat, S. (2024). On the suitability of a convolutional neural network based RCM-emulator for fine spatio-temporal precipitation. Climate Dynamics, 62(9), 8587-8613.
#
# [4] Baño-Medina, J., Manzanas, R., & Gutiérrez, J. M. (2021). On the suitability of deep convolutional neural networks for continental-wide downscaling of climate change projections. Climate Dynamics, 57(11), 2941-2951.
